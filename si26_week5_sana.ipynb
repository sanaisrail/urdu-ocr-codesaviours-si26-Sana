# %% [markdown]
# <a href="https://colab.research.google.com/github/sanaisrail/urdu-ocr-codesaviours-si26-Sana/blob/main/si26_week5_sana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U huggingface_hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 784.9/784.9 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 80.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: hf-xet
#     Found existing installation: hf-xet 1.5.1
#     Uninstalling hf-xet-1.5.1:
#       Successfully uninstalled hf-xet-1.5.1
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.23.0
#     Uninstalling huggingface_hub-1.23.0:
#       Successfully uninstalled huggingface_hub-1.23.0
# ...

# %%
from huggingface_hub import login, upload_folder

login()
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>C03W-R1EX</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center>Login successful. Logged in as <b>sanaisrail</b> (token: <code>oauth-sanaisrail</code>).<br>This token will be refreshed automatically when it expires.</center>

# %%
repo_id = "sana123/urdu_trocr_model"

# %%
from huggingface_hub import create_repo

repo_id = "sanaisrail/urdu_trocr_model"

create_repo(
    repo_id=repo_id,
    repo_type="model",
    exist_ok=True
)

print("Repository ready:", repo_id)
# Out:
# Repository ready: sanaisrail/urdu_trocr_model

# %%
from huggingface_hub import create_repo, upload_folder

repo_id = "sanaisrail/SI26-urdu-ocr-model"

create_repo(
    repo_id=repo_id,
    repo_type="model",
    exist_ok=True
)

upload_folder(
    folder_path="/content/drive/MyDrive/SI26-urdu-ocr-model",
    repo_id=repo_id,
    repo_type="model"
)
# Out:
# CommitInfo(commit_url='https://huggingface.co/sanaisrail/SI26-urdu-ocr-model/commit/a59061ed993e4236b8cf3e27d63f486259f0ab7d', commit_message='Upload folder using huggingface_hub', commit_description='', oid='a59061ed993e4236b8cf3e27d63f486259f0ab7d', pr_url=None, repo_url=RepoUrl('https://huggingface.co/sanaisrail/SI26-urdu-ocr-model', endpoint='https://huggingface.co', repo_type='model', repo_id='sanaisrail/SI26-urdu-ocr-model'), pr_revision=None, pr_num=None)

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 51.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 61.8 MB/s eta 0:00:00
# ...

# %%
# %%writefile app.py

import streamlit as st
from transformers import TrOCRProcessor, VisionEncoderDecoderModel
from PIL import Image
import torch

# Page settings
st.set_page_config(
    page_title="Urdu OCR - Code Saviours SI-26",
    page_icon="📝"
)

st.title("Urdu OCR — Code Saviours SI-26")
st.write("Upload an image containing Urdu text and get the extracted text.")

# Hugging Face model
model_path = "Nadianaz/SI26-urdu-ocr-model-nadia"

@st.cache_resource
def load_model():
    processor = TrOCRProcessor.from_pretrained(model_path)
    model = VisionEncoderDecoderModel.from_pretrained(model_path)
    model.eval()
    return processor, model

processor, model = load_model()

# Upload image
uploaded_file = st.file_uploader(
    "Upload Urdu Image",
    type=["png", "jpg", "jpeg"]
)

if uploaded_file is not None:

    image = Image.open(uploaded_file).convert("RGB")

    st.image(image, caption="Uploaded Urdu Image")

    if st.button("Extract Urdu Text"):

        pixel_values = processor(
            image,
            return_tensors="pt"
        ).pixel_values

        with torch.no_grad():
            generated_ids = model.generate(pixel_values)

        text = processor.batch_decode(
            generated_ids,
            skip_special_tokens=True
        )[0]

        if text:
            st.subheader("Extracted Urdu Text")
            st.write(text)
        else:
            st.write("Could not extract text from this image.")
# Out:
# Writing app.py

# %%
with open("app.py", "r") as f:
    print(f.read())
# Out:
# import streamlit as st
# from transformers import TrOCRProcessor, VisionEncoderDecoderModel
# from PIL import Image
# import torch
#
# # Page settings
# st.set_page_config(
#     page_title="Urdu OCR - Code Saviours SI-26",
#     page_icon="📝"
# )
#
# st.title("Urdu OCR — Code Saviours SI-26")
# st.write("Upload an image containing Urdu text and get the extracted text.")
#
# # Hugging Face model
# model_path = "Nadianaz/SI26-urdu-ocr-model-nadia"
#
# @st.cache_resource
# def load_model():
#     processor = TrOCRProcessor.from_pretrained(model_path)
#     model = VisionEncoderDecoderModel.from_pretrained(model_path)
#     model.eval()
#     return processor, model
#
# processor, model = load_model()
#
# # Upload image
# uploaded_file = st.file_uploader(
#     "Upload Urdu Image",
#     type=["png", "jpg", "jpeg"]
# )
#
# if uploaded_file is not None:
#
#     image = Image.open(uploaded_file).convert("RGB")
#
#     st.image(image, caption="Uploaded Urdu Image")
#
# ...
